# %% [markdown]
# # Importing and cleaning data
# This notebook will clean data from the California Department of Education for the analysis. Our goal is to merge all the data into a single cohesive geodataframe, which will happen in a subsequent notebook.
#
#  - [lcff data](https://ias.cde.ca.gov/lcffsnapshot/lcff.aspx)
#  - [grades](https://www.cde.ca.gov/ta/ac/cm/datafilesfall18.asp)
#  - [demographics/shapefiles](https://gis.data.ca.gov/datasets/e9476c422f0842a7a38652aaf4c7597c_0?geometry=-174.879%2C31.049%2C-63.126%2C43.258)
#
# Datasets last downloaded - 9/2/20

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_column', 200)

# %% [markdown]
# ## LCFF data

# %%
lcff = pd.read_csv('raw_data/lcffsnapshot18an.csv')
# import lcff data from source

# %%
lcff.columns = lcff.columns.str.strip()
# strip leading/trailing spaces

# %%
lcff.drop(lcff.tail(1).index,inplace=True)
# extracting state totals, removing from df

# %%
lcff.head()
# Out:
#   County Code  District Code  School Code  \
# 0          01        10017.0     112607.0
# 1          01        10017.0     123968.0
# 2          01        10017.0     124172.0
# 3          01        10017.0     125567.0
# 4          01        10017.0     131581.0
#
#                   Local Educational Agency  Charter Number  \
# 0   Envision Academy for Arts & Technology           811.0
# 1  Community School for Creative Education          1284.0
# 2                          Yu Ming Charter          1296.0
# 3                 Urban Montessori Charter          1383.0
# 4              Oakland Unity Middle School          1707.0
#
#   TK/K-3 ADA\nTarget, B-5/B-1 4 - 6 ADA\nTarget, B-6/B-2  \
# 0                        -                          -
# 1                     125.80                      66.49
# 2                     252.38                     134.11
# 3                     271.70                     101.50
# 4                        -                        61.99
#
#   7 - 8 ADA\nTarget, B-7/B-3 9 - 12 ADA\nTarget, B-8/B-4  \
# 0                       -                        359.23
# 1                     32.89                         -
# 2                     48.83                         -
# 3                     26.45                         -
# 4                    109.29                         -
#
#   Unduplicated Pupil Percentage\nTarget, D-1 Base Grant Funding\nTarget, C-5  \
# 0                                    0.7785                      $3,329,703
# 1                                    0.7936                       1,795,769
# 2                                    0.1892                       3,474,375
# 3                                    0.3756                       3,212,111
# 4                                    0.9199                       1,321,351
#
#   Supplemental Grant Funding\nTarget, D-7  \
# 0                               $518,435
# 1                                285,024
# 2                                131,471
# 3                                241,293
# 4                                243,103
#
#   Concentration Grant Funding\nTarget, E-8  \
# 0                                $362,605
# 1                                 195,559
# 2                                       -
# 3                                       -
# 4                                 143,896
#
#   Necessary Small Schools Allowance\nTarget, F-1  \
# 0                                           N/A
# 1                                           N/A
# 2                                           N/A
# 3                                           N/A
# 4                                           N/A
#
#   Add-On (Based on 2012-13 Targeted Instructional Improvement Block Grant)\nTarget, F-2  \
# 0                                               N/A
# 1                                               N/A
# 2                                               N/A
# 3                                               N/A
# 4                                               N/A
#
#   Add-On (Based on 2012-13 Home-to-School Transportation)\nTarget, F-3  \
# 0                                               N/A
# 1                                               N/A
# 2                                               N/A
# 3                                               N/A
# 4                                               N/A
#
#   Add-On (Based on 2012-13 Small School District Bus Replacement Program)\nTarget, F-4  \
# 0                                               N/A
# 1                                               N/A
# 2                                               N/A
# 3                                               N/A
# 4                                               N/A
#
#   Total LCFF Target Entitlement\nTarget, G-1/F-1  \
# 0                                    $4,210,743
# 1                                     2,276,352
# 2                                     3,605,846
# 3                                     3,453,404
# 4                                     1,708,350
#
#   Total LCFF Floor Entitlement\nTransition, B-13  \
# 0                                    $3,871,076
# 1                                     2,124,388
# 2                                     3,388,539
# 3                                     3,238,948
# 4                                     1,620,979
#
#   Current Year Gap Funding (100%)\nTransition, C-3  \
# 0                                        $339,667
# 1                                         151,964
# 2                                         217,307
# 3                                         214,456
# 4                                          87,371
#
#   Economic Recovery Target\nTransition, D-1  \
# 0                                       $-
# 1                                        -
# 2                                        -
# 3                                        -
# 4                                        -
#
#   Miscellaneous Adjustments\nTransition, E-1  \
# 0                                        $-
# 1                                         -
# 2                                         -
# 3                                         -
# 4                                         -
#
#   Total Local Revenue or In-Lieu of Property Taxes\nTransition, F-2/F-7  \
# 0                                          $894,989
# 1                                           561,016
# 2                                                 -
# 3                                           995,692
# 4                                           426,729
#
#   Education Protection Account Entitlement\nTransition, F-5/F-9  \
# 0                                          $683,070
# 1                                           354,307
# 2                                           683,750
# 3                                           627,724
# 4                                            34,256
#
#   Net State Aid\nTransition, F-6/F-10  \
# 0                         $2,632,684
# 1                          1,361,029
# 2                          2,922,096
# 3                          1,829,988
# 4                          1,247,365
#
#   Additional SA for MSA Guarantee\nTransition, H-1/H-2
# 0                                                $-
# 1                                                 -
# 2                                                 -
# 3                                                 -
# 4                                                 -

# %%
lcff = lcff.fillna(0)
lcff['County Code'] = lcff['County Code'].astype(str)
lcff['District Code'] = lcff['District Code'].astype(int)
lcff['District Code'] = lcff['District Code'].astype(str)
lcff['School Code'] = lcff['School Code'].astype(int)
lcff['School Code'] = lcff['School Code'].astype(str)
# changing to strings
# slicing by district level cds code

# %%
lcff['School Code'] = lcff['School Code'].apply(lambda x: '{0:0>7}'.format(x))
# front fill school codes to == 7

# %%
lcff
# Out:
#                                             County Code District Code  \
# 0                                                    01         10017
# 1                                                    01         10017
# 2                                                    01         10017
# 3                                                    01         10017
# 4                                                    01         10017
# ...                                                 ...           ...
# 2242                                       STATE TOTALS             0
# 2243  NOTE: Some LEAs may not display funding data d...             0
# 2244                                       Prepared by:             0
# 2245                 California Department of Education             0
# 2246                    School Fiscal Services Division             0
#
#      School Code                 Local Educational Agency  Charter Number  \
# 0        0112607   Envision Academy for Arts & Technology           811.0
# 1        0123968  Community School for Creative Education          1284.0
# 2        0124172                          Yu Ming Charter          1296.0
# 3        0125567                 Urban Montessori Charter          1383.0
# 4        0131581              Oakland Unity Middle School          1707.0
# ...          ...                                      ...             ...
# 2242     0000000                                        0             0.0
# 2243     0000000                                        0             0.0
# 2244     0000000                                        0             0.0
# 2245     0000000                                        0             0.0
# 2246     0000000                                        0             0.0
#
#      TK/K-3 ADA\nTarget, B-5/B-1 4 - 6 ADA\nTarget, B-6/B-2  \
# 0                           -                          -
# 1                        125.80                      66.49
# 2                        252.38                     134.11
# 3                        271.70                     101.50
# 4                           -                        61.99
# ...                          ...                        ...
# 2242               1,813,000.84               1,361,446.53
# 2243                           0                          0
# 2244                           0                          0
# 2245                           0                          0
# 2246                           0                          0
#
#      7 - 8 ADA\nTarget, B-7/B-3 9 - 12 ADA\nTarget, B-8/B-4  \
# 0                          -                        359.23
# 1                        32.89                         -
# 2                        48.83                         -
# 3                        26.45                         -
# 4                       109.29                         -
# ...                         ...                         ...
# 2242                923,799.16                1,855,585.57
# 2243                          0                           0
# 2244                          0                           0
# 2245                          0                           0
# 2246                          0                           0
#
#      Unduplicated Pupil Percentage\nTarget, D-1  \
# 0                                       0.7785
# 1                                       0.7936
# 2                                       0.1892
# 3                                       0.3756
# 4                                       0.9199
# ...                                         ...
# 2242                                          0
# 2243                                          0
# 2244                                          0
# 2245                                          0
# 2246                                          0
#
#      Base Grant Funding\nTarget, C-5 Supplemental Grant Funding\nTarget, D-7  \
# 0                        $3,329,703                                $518,435
# 1                         1,795,769                                 285,024
# 2                         3,474,375                                 131,471
# 3                         3,212,111                                 241,293
# 4                         1,321,351                                 243,103
# ...                              ...                                     ...
# 2242                $49,569,226,529                          $6,189,112,345
# 2243                               0                                       0
# 2244                               0                                       0
# 2245                               0                                       0
# 2246                               0                                       0
#
#      Concentration Grant Funding\nTarget, E-8  \
# 0                                   $362,605
# 1                                    195,559
# 2                                          -
# 3                                          -
# 4                                    143,896
# ...                                       ...
# 2242                          $3,473,165,908
# 2243                                        0
# 2244                                        0
# 2245                                        0
# 2246                                        0
#
#      Necessary Small Schools Allowance\nTarget, F-1  \
# 0                                              N/A
# 1                                              N/A
# 2                                              N/A
# 3                                              N/A
# 4                                              N/A
# ...                                             ...
# 2242                                  $100,474,970
# 2243                                              0
# 2244                                              0
# 2245                                              0
# 2246                                              0
#
#      Add-On (Based on 2012-13 Targeted Instructional Improvement Block Grant)\nTarget, F-2  \
# 0                                                  N/A
# 1                                                  N/A
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ...                                                 ...
# 2242                                      $855,045,830
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
#      Add-On (Based on 2012-13 Home-to-School Transportation)\nTarget, F-3  \
# 0                                                  N/A
# 1                                                  N/A
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ...                                                 ...
# 2242                                      $461,199,504
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
#      Add-On (Based on 2012-13 Small School District Bus Replacement Program)\nTarget, F-4  \
# 0                                                  N/A
# 1                                                  N/A
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ...                                                 ...
# 2242                                        $4,112,421
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
#      Total LCFF Target Entitlement\nTarget, G-1/F-1  \
# 0                                       $4,210,743
# 1                                        2,276,352
# 2                                        3,605,846
# 3                                        3,453,404
# 4                                        1,708,350
# ...                                             ...
# 2242                               $60,652,337,507
# 2243                                              0
# 2244                                              0
# 2245                                              0
# 2246                                              0
#
#      Total LCFF Floor Entitlement\nTransition, B-13  \
# 0                                       $3,871,076
# 1                                        2,124,388
# 2                                        3,388,539
# 3                                        3,238,948
# 4                                        1,620,979
# ...                                             ...
# 2242                               $56,805,139,260
# 2243                                              0
# 2244                                              0
# 2245                                              0
# 2246                                              0
#
#      Current Year Gap Funding (100%)\nTransition, C-3  \
# 0                                           $339,667
# 1                                            151,964
# 2                                            217,307
# 3                                            214,456
# 4                                             87,371
# ...                                               ...
# 2242                                  $3,934,385,946
# 2243                                                0
# 2244                                                0
# 2245                                                0
# 2246                                                0
#
#      Economic Recovery Target\nTransition, D-1  \
# 0                                          $-
# 1                                           -
# 2                                           -
# 3                                           -
# 4                                           -
# ...                                        ...
# 2242                              $45,891,349
# 2243                                         0
# 2244                                         0
# 2245                                         0
# 2246                                         0
#
#      Miscellaneous Adjustments\nTransition, E-1  \
# 0                                           $-
# 1                                            -
# 2                                            -
# 3                                            -
# 4                                            -
# ...                                         ...
# 2242                                 $(134,316)
# 2243                                          0
# 2244                                          0
# 2245                                          0
# 2246                                          0
#
#      Total Local Revenue or In-Lieu of Property Taxes\nTransition, F-2/F-7  \
# 0                                             $894,989
# 1                                              561,016
# 2                                                    -
# 3                                              995,692
# 4                                              426,729
# ...                                                 ...
# 2242                                   $20,313,234,098
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
#      Education Protection Account Entitlement\nTransition, F-5/F-9  \
# 0                                             $683,070
# 1                                              354,307
# 2                                              683,750
# 3                                              627,724
# 4                                               34,256
# ...                                                 ...
# 2242                                    $7,649,112,824
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
#      Net State Aid\nTransition, F-6/F-10  \
# 0                            $2,632,684
# 1                             1,361,029
# 2                             2,922,096
# 3                             1,829,988
# 4                             1,247,365
# ...                                  ...
# 2242                    $33,596,775,929
# 2243                                   0
# 2244                                   0
# 2245                                   0
# 2246                                   0
#
#      Additional SA for MSA Guarantee\nTransition, H-1/H-2
# 0                                                   $-
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                    -
# ...                                                 ...
# 2242                                      $144,408,593
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
# [2247 rows x 26 columns]

# %%
lcff = lcff.loc[lcff['School Code'] == '0000000']
# select districts, district entries do not have a school level cds code

# %%
lcff['cds'] = lcff['County Code'] + lcff['District Code'] + lcff['School Code']
# combining into full cds code
col_name='cds'
first_col = lcff.pop(col_name)
lcff.insert(0, col_name, first_col)
# moving to front
lcff.drop('County Code', axis=1, inplace=True)
lcff.drop('School Code', axis=1, inplace=True)
# dropping excess
# Out:
# <ipython-input-10-1bcaa33e1b00>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lcff['cds'] = lcff['County Code'] + lcff['District Code'] + lcff['School Code']
# /home/serge/anaconda3/envs/dev/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
lcff = lcff.rename(columns={'Charter Number': 'charter_number',
                     'Unduplicated Pupil Percentage\nTarget, D-1': 'unduplicated_pupil_percentage',
                     'Base Grant Funding\nTarget, C-5': 'base_grant',
                     'Supplemental Grant Funding\nTarget, D-7': 'supplemental_grant',
                     'Concentration Grant Funding\nTarget, E-8': 'concentration_grant',
                     'Total LCFF Target Entitlement\nTarget, G-1/F-1': 'total_grants',
                     'Necessary Small Schools Allowance\nTarget, F-1': 'nec_small_schools',
                     'Local Educational Agency' : 'districtname'      
                           })

# %%
lcff.tail(7)
# gotta drop the last 5 rows
# Out:
#                                                     cds District Code  \
# 2239                                     58727510000000         72751
# 2241                                     58727690000000         72769
# 2242                               STATE TOTALS00000000             0
# 2243  NOTE: Some LEAs may not display funding data d...             0
# 2244                               Prepared by:00000000             0
# 2245         California Department of Education00000000             0
# 2246            School Fiscal Services Division00000000             0
#
#               districtname  charter_number TK/K-3 ADA\nTarget, B-5/B-1  \
# 2239             Wheatland             0.0                     580.88
# 2241  Wheatland Union High             0.0                        -
# 2242                     0             0.0               1,813,000.84
# 2243                     0             0.0                           0
# 2244                     0             0.0                           0
# 2245                     0             0.0                           0
# 2246                     0             0.0                           0
#
#      4 - 6 ADA\nTarget, B-6/B-2 7 - 8 ADA\nTarget, B-7/B-3  \
# 2239                    389.53                     284.05
# 2241                       -                          -
# 2242              1,361,446.53                 923,799.16
# 2243                          0                          0
# 2244                          0                          0
# 2245                          0                          0
# 2246                          0                          0
#
#      9 - 12 ADA\nTarget, B-8/B-4 unduplicated_pupil_percentage  \
# 2239                        -                          0.4783
# 2241                     761.94                        0.4283
# 2242               1,855,585.57                              0
# 2243                           0                             0
# 2244                           0                             0
# 2245                           0                             0
# 2246                           0                             0
#
#              base_grant supplemental_grant concentration_grant  \
# 2239         9,947,133            951,543                   -
# 2241         7,062,422            604,967                   -
# 2242   $49,569,226,529     $6,189,112,345      $3,473,165,908
# 2243                  0                  0                   0
# 2244                  0                  0                   0
# 2245                  0                  0                   0
# 2246                  0                  0                   0
#
#      nec_small_schools  \
# 2239                -
# 2241                -
# 2242     $100,474,970
# 2243                 0
# 2244                 0
# 2245                 0
# 2246                 0
#
#      Add-On (Based on 2012-13 Targeted Instructional Improvement Block Grant)\nTarget, F-2  \
# 2239                                            97,971
# 2241                                                 -
# 2242                                      $855,045,830
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
#      Add-On (Based on 2012-13 Home-to-School Transportation)\nTarget, F-3  \
# 2239                                           237,702
# 2241                                           185,239
# 2242                                      $461,199,504
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
#      Add-On (Based on 2012-13 Small School District Bus Replacement Program)\nTarget, F-4  \
# 2239                                                 -
# 2241                                                 -
# 2242                                        $4,112,421
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
#            total_grants Total LCFF Floor Entitlement\nTransition, B-13  \
# 2239        11,234,349                                     10,546,226
# 2241         7,852,628                                      7,260,075
# 2242   $60,652,337,507                                $56,805,139,260
# 2243                  0                                              0
# 2244                  0                                              0
# 2245                  0                                              0
# 2246                  0                                              0
#
#      Current Year Gap Funding (100%)\nTransition, C-3  \
# 2239                                         688,123
# 2241                                         592,553
# 2242                                  $3,934,385,946
# 2243                                                0
# 2244                                                0
# 2245                                                0
# 2246                                                0
#
#      Economic Recovery Target\nTransition, D-1  \
# 2239                                  309,994
# 2241                                        -
# 2242                              $45,891,349
# 2243                                         0
# 2244                                         0
# 2245                                         0
# 2246                                         0
#
#      Miscellaneous Adjustments\nTransition, E-1  \
# 2239                                         -
# 2241                                         -
# 2242                                 $(134,316)
# 2243                                          0
# 2244                                          0
# 2245                                          0
# 2246                                          0
#
#      Total Local Revenue or In-Lieu of Property Taxes\nTransition, F-2/F-7  \
# 2239                                         1,007,306
# 2241                                         2,191,152
# 2242                                   $20,313,234,098
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
#      Education Protection Account Entitlement\nTransition, F-5/F-9  \
# 2239                                         1,944,794
# 2241                                         1,422,027
# 2242                                    $7,649,112,824
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0
#
#      Net State Aid\nTransition, F-6/F-10  \
# 2239                          8,592,243
# 2241                          4,239,449
# 2242                    $33,596,775,929
# 2243                                   0
# 2244                                   0
# 2245                                   0
# 2246                                   0
#
#      Additional SA for MSA Guarantee\nTransition, H-1/H-2
# 2239                                                 -
# 2241                                                 -
# 2242                                      $144,408,593
# 2243                                                  0
# 2244                                                  0
# 2245                                                  0
# 2246                                                  0

# %%
lcff.drop(lcff.tail(5).index,inplace=True)

# %%
# renaming for readability
lcff = lcff[[  'districtname',
               'unduplicated_pupil_percentage', 
               'base_grant', 
               'supplemental_grant', 
               'concentration_grant', 
               'total_grants', 
               'cds' ]].copy()
# copying relevant columns into a new dataframe

lcff['cds'] = lcff['cds'].astype(float)

# %%
# !mkdir clean_data
# Out:
# mkdir: cannot create directory ‘clean_data’: File exists

# %%
lcff.to_csv("clean_data/lcff.csv")
# save to disk

# %% [markdown]
# ## Grade data

# %% [markdown]
# ### Math first

# %%
math = pd.read_csv('raw_data/mathdownload2018.csv')
# Out:
# /home/serge/anaconda3/envs/dev/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (6,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [raw]
# This cell created a dictionary to replace the abbreviated student codes with more descriptive names. I do not use it because in a later data structure, the abbreviated names are more concise when indicating either math or english, AND current vs prior vs change grades, but I retain the cell here in case I want to use this format to execute column name replacements in the future.
#
# replacements = dict(
#     studentgroup = {'ALL':'all_students',
#                         'AA':'african_american',
#                         'AI':'american_indian',
#                         'AS':'asian',
#                         'FI':'filipino',
#                         'HI':'hispanic',
#                         'PI':'pacific_islander',
#                         'WH':'white',
#                         'MR':'multiple_races',
#                         'EL':'english_learners',
#                         'ELO':'english_learners_only',
#                         'RFP':'rfep_only',
#                         'EO':'english_only',
#                         'SED':'ses_disad',
#                         'SWD':'disabilities',
#                         'FOS':'foster_youth',
#                         'HOM':'homeless_youth',
#                 })
#
#
# math['studentgroup'].astype(str)
# math = math.replace(replacements)
# # replace student group codes

# %% [markdown]
# fixing cds codes to match to enable merges

# %%
math['cds'].astype(str)
# changing to string
math = math[math.coe_flag !='Y']
# removing county offices of education
math = math.loc[math['rtype'] == 'D']
# select district-level performance
math['cds'] = math['cds'].apply(lambda x: '{0:0>14}'.format(x))
# adding leading zero to 13 digit int
math['District Code'] = [x[2:7] for x in math['cds']]
# adding district only code

# %%
math = pd.concat([math.pop(x) for x in ['District Code',
                                          'districtname',                                          
                                          'studentgroup', 
                                          'currstatus', 
                                          'priorstatus', 
                                          'change',
                                          'countyname']],
                    1)
# slice out columns

# %%
math
# Out:
#        District Code          districtname studentgroup  currstatus  \
# 163            61119       Alameda Unified           AA       -83.9
# 164            61119       Alameda Unified           AI       -51.8
# 165            61119       Alameda Unified          ALL        14.3
# 166            61119       Alameda Unified           AS        43.6
# 167            61119       Alameda Unified           EL       -13.7
# ...              ...                   ...          ...         ...
# 148683         72769  Wheatland Union High           PI         NaN
# 148684         72769  Wheatland Union High          RFP         NaN
# 148685         72769  Wheatland Union High          SED       -90.0
# 148686         72769  Wheatland Union High          SWD      -226.6
# 148687         72769  Wheatland Union High           WH       -42.3
#
#         priorstatus  change countyname
# 163           -82.8    -1.1    Alameda
# 164           -50.0    -1.8    Alameda
# 165            10.8     3.4    Alameda
# 166            44.8    -1.2    Alameda
# 167           -12.9    -0.9    Alameda
# ...             ...     ...        ...
# 148683          NaN     NaN       Yuba
# 148684          NaN     NaN       Yuba
# 148685        -74.0   -16.0       Yuba
# 148686          NaN     NaN       Yuba
# 148687        -57.0    14.7       Yuba
#
# [13603 rows x 7 columns]

# %%
math.to_csv("clean_data/math.csv")
# save to disk

# %% [markdown]
# ### English grades now

# %%
ela = pd.read_csv('raw_data/eladownload2018.csv')
# Out:
# /home/serge/anaconda3/envs/dev/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (6,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# fixing cds codes to match to enable merges

# %%
ela['cds'].astype(str)
# changing cds code to string
ela = ela[ela.coe_flag !='Y']
# removing county offices of education
ela = ela.loc[ela['rtype'] == 'D']
# select district level entries
ela['cds'] = ela['cds'].apply(lambda x: '{0:0>14}'.format(x))
# adding leading zero to 13 digit int
ela['District Code'] = [x[2:7] for x in ela['cds']]

# %%
#creating district-level ela performance variable (dictionary)
ela = pd.concat([ela.pop(x) for x in ['District Code',
                                          'districtname',                                          
                                          'studentgroup', 
                                          'currstatus', 
                                          'priorstatus', 
                                          'change',
                                          'countyname']],
                    1)
# slice out columns

# %%
ela.to_csv("clean_data/ela.csv")
# save to disk

# %% [markdown]
# ## Student attribute and shapefile data

# %% [markdown]
# This requires geopandas.

# %%
import geopandas as gpd

# %%
t = gpd.read_file("raw_data/DistrictAreas1819.shp")

# %%
t.to_file("clean_data/attributes.shp")
# save to disk

# %% [markdown]
# ## Downloading the ltdb with Geosnap

# %% [markdown]
# We need to download the data that geosnap uses to construct its 'commuinity' class. see the [geosnap user guide](https://spatialucr.github.io/geosnap-guide/content/01_getting_started.html)

# %%
from geosnap.io import store_ltdb
# Out:
# /home/serge/anaconda3/envs/dev/lib/python3.8/site-packages/geosnap/_data.py:122: UserWarning: Unable to locate local census data. Streaming instead.
# If you plan to use census data repeatedly you can store it locally with the io.store_census function for better performance
#   warn(
# Downloading manifest: 100%|██████████| 1.27k/1.27k [00:02<00:00, 577B/s]
# Loading manifest: 100%|██████████| 5/5 [00:00<00:00, 1425.18entries/s]
# Downloading manifest: 100%|██████████| 1.22k/1.22k [00:02<00:00, 570B/s]
# Loading manifest: 100%|██████████| 5/5 [00:00<00:00, 1635.08entries/s]

# %%
import geosnap

# %%
sample = "D:/github/finalcapstone/raw_data/LTDB_Std_All_Sample.zip"
full = "D:/github/finalcapstone/raw_data/LTDB_Std_All_fullcount.zip"
# definitely add these files to the .gitignore file

geosnap.io.store_ltdb(sample=sample, fullcount=full)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-de587050f1c2> in <module>
#       3 # definitely add these files to the .gitignore file
#       4
# ----> 5 geosnap.io.store_ltdb(sample=sample, fullcount=full)
#
# ~/anaconda3/envs/dev/lib/python3.8/site-packages/geosnap/io/storage.py in store_ltdb(sample, fullcount)
#      95
#      96     """
# ---> 97     sample_zip = zipfile.ZipFile(sample)
#      98     fullcount_zip = zipfile.ZipFile(fullcount)
#      99
#
# ~/anaconda3/envs/dev/lib/python3.8/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/github/finalcapstone/raw_data/LTDB_Std_All_Sample.zip'
