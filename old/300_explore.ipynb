# %%
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_column', 200)

# %%
gdf = gpd.read_file("clean_data/master.shp")

# %% [markdown]
# ## Purpose
#
# Our purpose is to understand the effects of the `concentration grant` on academic performance.
#
# ## <s>Structure</s> (outdated)
# The general structure of the dataset is as follows:
#
# - **county**<br>
#
# _58 in the state - top level deliniator._
#
#
# - county
#     - **school district**<br>
#
# _Within each county, a number of school districts. We have demographic profiles of each district that we can use in the matching process, if applicable._
#
#
# - county
#     - school district
#         - **student group**<br>
#
# _Further, the grade data breaks down into 17 student groups per district. Using this we can query academic performance by a specific group._
#
#
# - county
#     - school district
#         - student group
#             - **math grades**
#             - **english grades**<br>
#
# _Finally, the specific math and english grades lie at the bottom of the data structure._

# %%
#gdf

# %% [markdown]
# ## Conflicting data
#
# A key indicator for defining classes of school districts is the Unduplicated Pupil Count (UPC), the share of students which qualify as high needs as defined under California SB-97. Because it is a key indicator, two data sources include it. Unfortunately, the two sources provide different values for the same indicator. `UPpct` is the UPC as defined by the attributes dataset. From the source [website](https://gis.data.ca.gov/datasets/e9476c422f0842a7a38652aaf4c7597c_0?geometry=-146.710%2C31.049%2C-91.295%2C43.258):
#
# > Boundary lines are maintained by the California Department of Education (CDE) and are effective in the 2018-19 academic year . The CDE works collaboratively with the US Census Bureau to update and maintain boundary information as part of the federal School District Review Program (SDRP).
#
# The second variable, `unduplicat` comes from the [LCFF funding snapshot](https://ias.cde.ca.gov/lcffsnapshot/lcff.aspx), which is less recent, without the collaboration of the census, and lacks the polish that the collaboration brought.
#
# Our issue is that `UPpct` and `unduplicat` are different values, despite representing the same variable.
#
# Let's investigate the depths of the differences between the two attributes.

# %%
gdf.UPpct
# Out:
# 0      0.335
# 1      0.304
# 2      0.334
# 3      0.296
# 4      0.831
#        ...
# 939    0.812
# 940    0.816
# 941    0.387
# 942    0.486
# 943    0.446
# Name: UPpct, Length: 944, dtype: float64

# %%
gdf.unduplicat
# Out:
# 0      0.3486
# 1      0.2833
# 2      0.3519
# 3      0.2904
# 4      0.7953
#         ...
# 939    0.6988
# 940    0.8168
# 941    0.3868
# 942    0.4783
# 943    0.4283
# Name: unduplicat, Length: 944, dtype: float64

# %%
gdf['UPdiff'] = gdf['UPpct'] - gdf['unduplicat']
print(gdf['UPdiff'])
# Out:
# 0     -0.0136
# 1      0.0207
# 2     -0.0179
# 3      0.0056
# 4      0.0357
#         ...
# 939    0.1132
# 940   -0.0008
# 941    0.0002
# 942    0.0077
# 943    0.0177
# Name: UPdiff, Length: 944, dtype: float64

# %%
pd.Series.mean(gdf['UPdiff'])
# Out:
# 0.006848198789358151

# %%
pd.Series.median(gdf['UPdiff'])
# Out:
# 0.004999992370605499

# %% [markdown]
# On average, the difference between `UPpct` and `unduplicat` are very small. What about any extreme values?

# %%
pd.Series.max(gdf['UPdiff'])
# Out:
# 0.4074

# %% [markdown]
# this is kind of large, let's use the `shape` function to call a tuple indicating `(Nrows, NCollumns)` of the sliced dataframe.

# %%
gdf.loc[gdf['UPdiff'] > 0.05].shape
# number of districts where the difference is larger than 0.05.
# Out:
# (68, 183)

# %%
gdf.loc[gdf['UPdiff'] > 0.1].shape
# number of districts where the difference is larger than 0.1.
# Out:
# (17, 183)

# %%
gdf.loc[gdf['UPdiff'] > 0.2].shape
# number of districts where the difference is larger than 0.2.
# Out:
# (1, 183)

# %% [markdown]
# This gives us an idea of the extent of the conflicting data on this variable.

# %% [markdown]
# ## Visual exploration

# %%
f, ax = plt.subplots(figsize  = (12, 8))

ax.set_title("Share of UPC Student Body by District", fontsize=18)

gdf.plot(
    column='UPpct',
    legend=True,
    figsize=(15, 15),
    scheme="fisher_jenks", # 7 class fisher_jenks classification
    k=7,
    linewidth=.1,
    edgecolor='black',
    cmap='cividis_r',
    ax=ax
        )

# %% [markdown]
# The classification scheme impacts the visualization. Rather than using a standardized scheme, it might make more sense to use a user-defined classification to better distinguish districts that recieve concentration grants from districts that do not. That determining factor is the `unduplicated pupil count` or *UPC* of students which are disadvantaged in at least one of a few defined ways. A share of UPC of 0.55 or higher means that the district recieves a concentration grant.
#
# A user-defined classification to capture the cutoff for reciept of a concentration grant might look like this:
# - 0 -> 0.10
# - 0.10 -> 0.25
# - 0.25 -> 0.5499
# - 0.55 -> 0.70
# - 0.70 -> 1.0

# %%
x = (gdf['UPpct'])
# setting variable of interest
bins_list = [0.10, 0.25, 0.5499, 0.7, 1]
# setting bins
cm = plt.cm.cividis_r
# seting colormap

# %%
from legendgram import legendgram
import palettable.matplotlib as palmpl

# %%
f, (ax1, ax2) = plt.subplots(1,2, figsize=(19,10))

plt.title('Share of Disadvantaged Students by District')

gdf.plot(
    column='UPpct',
    legend=True,
    scheme='userdefined',
    classification_kwds={'bins':bins_list},
    linewidth=.1,
    edgecolor='black',
    cmap='viridis_r',
    ax=ax1
        )
ax1.set_title("Concentration of High Needs Students by District", fontsize=16)
# title for map

legendgram(f,ax2,x.values,bins_list,pal=palmpl.Viridis_5_r,
               legend_size=(1,.7), # legend size in fractions of the axis
               loc = 'lower left', # matplotlib-style legend locations
               clip = (0,1) # clip the displayed range of the histogram
               )

ax1.axis("off")
ax2.axis("off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# - What are the demographic makeups of each bin?

# %% [markdown]
# the darker polygons indicate a higher share of UPC, while the lighter districts have a lesser concentration of disadvantaged students. What happens if we further divide the top bin, the districts with the smallest share of UPC?

# %%
f, ax = plt.subplots(figsize=(12, 8))

gdf.plot(
    column='UPpct',
    legend=True,
    figsize=(15, 15),
    scheme='userdefined',
    classification_kwds={'bins':[0.05, 0.1, 0.25, 0.5499, 0.7, 1]},
    linewidth=.1,
    edgecolor='black',
    cmap='cividis_r',
    ax=ax
        )

# %% [markdown]
# This reveals that there are fewer highly priviledged/homogenized districts than the previous visualization led us to believe, but there are still some. It looks like the marjority of priviledged districts are somwhere between the `0.1` and `0.25` range of UPC.

# %% [markdown]
# Now lets put the original Fisher Jenks classification next to our user-defined 4-bin classification scheme.

# %%
f, ax = plt.subplots(ncols=2, figsize=(15, 15))
#two plots breaks title

gdf.plot(
    column='UPpct',
    legend=True,
    figsize=(15, 15),
    scheme="fisher_jenks",
    k=7,
    linewidth=.1,
    edgecolor='black',
    cmap='cividis_r',
    ax=ax[0]
        )

gdf.plot(
    column='UPpct',
    legend=True,
    figsize=(15, 15),
    scheme='userdefined',
    classification_kwds={'bins':[0.25, 0.5499, 0.7, 1]},
    linewidth=.1,
    edgecolor='black',
    cmap='cividis_r',
    ax=ax[1]
        )
# ax.set_title("Share of UPC Concentration, Fisher Jenks vs User Defined Classes")
# two plots side by side PogU

# %% [markdown]
# ## adding county boundaries
#
# [link to source](https://gis.data.ca.gov/datasets/CALFIRE-Forestry::california-county-boundaries?geometry=-146.710%2C31.049%2C-91.295%2C43.258)
#
# [geopandas docs](https://geopandas.org/mapping.html)
#
# Not sure if we need to merge these into the gdf or if it's possible, We might just keep the county boundaries for visualization purposes.

# %%
counties = gpd.read_file("raw_data/cnty19_1.shp")

# %%
counties.plot()

# %%
counties.head()
# Out:
#    OBJECTID COUNTY_NAM COUNTY_ABB  COUNTY_NUM COUNTY_COD COUNTY_FIP ISLAND  \
# 0         1    Alameda        ALA           1         01        001   None
# 1         2     Alpine        ALP           2         02        003   None
# 2         3     Amador        AMA           3         03        005   None
# 3         4      Butte        BUT           4         04        007   None
# 4         5  Calaveras        CAL           5         05        009   None
#
#                                  GlobalID     SHAPE_Leng    SHAPE_Area  \
# 0  {E6F92268-D2DD-4CFB-8B79-5B4B2F07C559}  308998.650975  3.402787e+09
# 1  {870479B2-480A-494B-8352-AD60578839C1}  274888.492662  3.146939e+09
# 2  {4F45B3A6-BE10-461C-8945-6B2AAA7119F6}  361708.438649  2.562635e+09
# 3  {44FBA680-AECC-4E04-A499-29D69AFFBD4A}  526547.113134  7.339348e+09
# 4  {D11EF739-4A1E-414E-BFD1-E7DCD56CD61E}  370637.579039  4.351069e+09
#
#                                             geometry
# 0  POLYGON ((-13611173.233 4566017.932, -13611061...
# 1  POLYGON ((-13312326.921 4680816.110, -13312311...
# 2  POLYGON ((-13366405.546 4679183.529, -13366408...
# 3  POLYGON ((-13478186.664 4807593.081, -13478502...
# 4  POLYGON ((-13360333.217 4641182.754, -13360329...

# %%
counties['geometry'].crs
# thankfully the same as our dataset
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World - 85°S to 85°N
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf['geometry'].crs
# see, I told you
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World - 85°S to 85°N
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax.set_aspect('equal')

gdf.plot(column='UPpct',
        legend=True,
        scheme='userdefined',
        classification_kwds={'bins':bins_list},
        linewidth=.1,
        edgecolor='white',
        cmap='cividis_r',
        ax=ax)

counties.boundary.plot(facecolor='none',
                       edgecolor='black',
                       linewidth=.75,
                       ax=ax)

# that was easy, actually

# %% [markdown]
# Attempting to merge

# %%
overlay = pd.merge(gdf, counties, left_on='CountyName', right_on='COUNTY_NAM', how='left')

# %%
overlay.head()
# Out:
#    index  OBJECTID_x     Year    FedID   CDCode        CDSCode CountyName  \
# 0    NaN           1  2018-19  0601770  0161119  1611190000000    Alameda
# 1    NaN           2  2018-19  0601860  0161127  1611270000000    Alameda
# 2    NaN           3  2018-19  0604740  0161143  1611430000000    Alameda
# 3    NaN           4  2018-19  0607800  0161150  1611500000000    Alameda
# 4    NaN           5  2018-19  0612630  0161168  1611680000000    Alameda
#
#               DistrictNa DistrictTy GradeLow GradeHigh GradeLowCe GradeHighC  \
# 0        Alameda Unified    Unified       KG        12         KG         12
# 1    Albany City Unified    Unified       KG        12         KG         12
# 2       Berkeley Unified    Unified       KG        12         KG         12
# 3  Castro Valley Unified    Unified       KG        12         KG         12
# 4          Emery Unified    Unified       KG        12         KG         12
#
#                   AssistStat CongressUS  SenateCA AssemblyCA  \
# 0  Differentiated Assistance         13        09         18
# 1         General Assistance         13        09         15
# 2  Differentiated Assistance         13        09         15
# 3         General Assistance      13,15  07,09,10      18,20
# 4  Differentiated Assistance         13        09         15
#
#              LocaleDist                                       UpdateNote  \
# 0  21 - Suburban, Large  2018-19 District Boundary Adjustment/Correction
# 1  21 - Suburban, Large  2018-19 District Boundary Adjustment/Correction
# 2    12 - City, Midsize  2018-19 District Boundary Adjustment/Correction
# 3  21 - Suburban, Large  2018-19 District Boundary Adjustment/Correction
# 4  21 - Suburban, Large  2018-19 District Boundary Adjustment/Correction
#
#    EnrollTota  EnrollChar  EnrollNonC  AAcount      AApct  AIcount  AIpct  \
# 0       11260        1877        9383      825   7.300000       28    0.2
# 1        3682           0        3682      111   3.000000        4    0.1
# 2       10194         383        9811     1440  14.100000       16    0.2
# 3        9269           0        9269      489   5.300000       19    0.2
# 4         743           0         743      326  43.900002        1    0.1
#
#    AScount      ASpct  FIcount  FIpct  HIcount      HIpct  MRcount  MRpct  \
# 0     2854  25.299999      683    6.1     1960  17.400000     1310   11.6
# 1     1063  28.900000       47    1.3      592  16.100000      510   13.9
# 2      731   7.200000       83    0.8     2438  23.900000     1465   14.4
# 3     2539  27.400000      420    4.5     2204  23.799999      909    9.8
# 4       83  11.200000       11    1.5      185  24.900000       62    8.3
#
#    PIcount  PIpct  WHcount      WHpct  NRcount  NRpct  ELcount  ELpct  \
# 0       67    0.6     3244  28.799999      289    2.6     1601   14.2
# 1        6    0.2     1163  31.600000      186    5.1      583   15.8
# 2       14    0.1     3999  39.200001        8    0.1      953    9.3
# 3       47    0.5     2480  26.799999      162    1.7     1021   11.0
# 4        8    1.1       67   9.000000        0    0.0      160   21.5
#
#    FOScount  FOSpct  HOMcount  HOMpct  MIGcount  MIGpct  SWDcount  SWDpct  \
# 0        26     0.2        67     0.6         0     0.0      1289    11.4
# 1         2     0.1        12     0.3         0     0.0       312     8.5
# 2        23     0.2       265     2.6         0     0.0      1148    11.3
# 3        12     0.1        68     0.7         0     0.0       800     8.6
# 4         1     0.1         7     0.9         0     0.0        55     7.4
#
#    SEDcount     SEDpct  UPcount  UPpct  ELATested  ELAStdMetP  MathTested  \
# 0      3523  31.299999     3144  0.335     4567.0   69.400002      4587.0
# 1       777  21.100000     1118  0.304     1773.0   79.199997      1795.0
# 2      3331  32.700001     3275  0.334     4614.0   66.699997      4549.0
# 3      2284  24.600000     2739  0.296     4844.0   68.099998      4850.0
# 4       600  80.800003      613  0.831      376.0   37.099998       377.0
#
#    MathStdMet  CCPrepCoho  CCPrepPct  AbsentElig  AbsentPct  GradCohort  \
# 0   59.700001       773.0  56.799999     11453.0        9.4       882.0
# 1   72.000000       302.0  62.599998      3763.0        6.4       301.0
# 2   61.700001       790.0  63.299999     10404.0        9.7       856.0
# 3   63.200001       737.0  57.099998      9433.0        7.4       742.0
# 4   23.299999        40.0  22.500000       760.0       20.5        40.0
#
#       GradPct  UCCSUReqMe  DropOutPct  EnrollCumu  SuspPct   SHAPE_Leng_x  \
# 0   88.900002   58.900002         5.2     11600.0      2.6   57196.403944
# 1   94.699997   63.900002         1.7      3830.0      1.9   12870.772156
# 2   87.400002   83.300003        10.7     10534.0      1.4   44426.287405
# 3   92.599998   55.900002         3.0      9532.0      2.2  142338.494091
# 4  100.000000   40.000000         0.0       780.0      3.6   13762.869292
#
#    SHAPE_Area_x  Unnamed__0             district_1  unduplicat  base_grant  \
# 0  4.733304e+07          10        Alameda Unified      0.3486  75,938,983
# 1  7.161276e+06          16    Albany City Unified      0.2833  29,644,972
# 2  4.376389e+07          17       Berkeley Unified      0.3519  78,556,532
# 3  2.833205e+08          19  Castro Valley Unified      0.2904  74,911,585
# 4  5.368212e+06          20          Emery Unified      0.7953   5,702,229
#
#   supplement concentrat  total_gran           cds District_C  e_chan_AA  \
# 0  5,294,466          -  82,158,116  1.611190e+12      11190        NaN
# 1  1,679,684          -  31,352,540  1.611270e+12      11270        NaN
# 2  5,528,808          -  89,369,621  1.611430e+12      11430        NaN
# 3  4,350,864          -  79,554,607  1.611500e+12      11500        NaN
# 4    906,997    699,378   7,326,875  1.611680e+12      11680        NaN
#
#    e_chan_AI  e_chan_ALL  e_chan_AS  e_chan_EL  e_chan_ELO  e_chan_EO  \
# 0        NaN         NaN        NaN        NaN         NaN        NaN
# 1        NaN         NaN        NaN        NaN         NaN        NaN
# 2        NaN         NaN        NaN        NaN         NaN        NaN
# 3        NaN         NaN        NaN        NaN         NaN        NaN
# 4        NaN         NaN        NaN        NaN         NaN        NaN
#
#    e_chan_FI  e_chan_FOS  e_chan_HI  e_chan_HOM  e_chan_MR  e_chan_PI  \
# 0        NaN         NaN        NaN         NaN        NaN        NaN
# 1        NaN         NaN        NaN         NaN        NaN        NaN
# 2        NaN         NaN        NaN         NaN        NaN        NaN
# 3        NaN         NaN        NaN         NaN        NaN        NaN
# 4        NaN         NaN        NaN         NaN        NaN        NaN
#
#    e_chan_RFP  e_chan_SED  e_chan_SWD  e_chan_WH  e_curr_AA  e_curr_AI  \
# 0         NaN         NaN         NaN        NaN        NaN        NaN
# 1         NaN         NaN         NaN        NaN        NaN        NaN
# 2         NaN         NaN         NaN        NaN        NaN        NaN
# 3         NaN         NaN         NaN        NaN        NaN        NaN
# 4         NaN         NaN         NaN        NaN        NaN        NaN
#
#    e_curr_ALL  e_curr_AS  e_curr_EL  e_curr_ELO  e_curr_EO  e_curr_FI  \
# 0         NaN        NaN        NaN         NaN        NaN        NaN
# 1         NaN        NaN        NaN         NaN        NaN        NaN
# 2         NaN        NaN        NaN         NaN        NaN        NaN
# 3         NaN        NaN        NaN         NaN        NaN        NaN
# 4         NaN        NaN        NaN         NaN        NaN        NaN
#
#    e_curr_FOS  e_curr_HI  e_curr_HOM  e_curr_MR  e_curr_PI  e_curr_RFP  \
# 0         NaN        NaN         NaN        NaN        NaN         NaN
# 1         NaN        NaN         NaN        NaN        NaN         NaN
# 2         NaN        NaN         NaN        NaN        NaN         NaN
# 3         NaN        NaN         NaN        NaN        NaN         NaN
# 4         NaN        NaN         NaN        NaN        NaN         NaN
#
#    e_curr_SED  e_curr_SWD  e_curr_WH  e_prio_AA  e_prio_AI  e_prio_ALL  \
# 0         NaN         NaN        NaN        NaN        NaN         NaN
# 1         NaN         NaN        NaN        NaN        NaN         NaN
# 2         NaN         NaN        NaN        NaN        NaN         NaN
# 3         NaN         NaN        NaN        NaN        NaN         NaN
# 4         NaN         NaN        NaN        NaN        NaN         NaN
#
#    e_prio_AS  e_prio_EL  e_prio_ELO  e_prio_EO  e_prio_FI  e_prio_FOS  \
# 0        NaN        NaN         NaN        NaN        NaN         NaN
# 1        NaN        NaN         NaN        NaN        NaN         NaN
# 2        NaN        NaN         NaN        NaN        NaN         NaN
# 3        NaN        NaN         NaN        NaN        NaN         NaN
# 4        NaN        NaN         NaN        NaN        NaN         NaN
#
#    e_prio_HI  e_prio_HOM  e_prio_MR  e_prio_PI  e_prio_RFP  e_prio_SED  \
# 0        NaN         NaN        NaN        NaN         NaN         NaN
# 1        NaN         NaN        NaN        NaN         NaN         NaN
# 2        NaN         NaN        NaN        NaN         NaN         NaN
# 3        NaN         NaN        NaN        NaN         NaN         NaN
# 4        NaN         NaN        NaN        NaN         NaN         NaN
#
#    e_prio_SWD  e_prio_WH  m_chan_AA  m_chan_AI  m_chan_ALL  m_chan_AS  \
# 0         NaN        NaN        NaN        NaN         NaN        NaN
# 1         NaN        NaN        NaN        NaN         NaN        NaN
# 2         NaN        NaN        NaN        NaN         NaN        NaN
# 3         NaN        NaN        NaN        NaN         NaN        NaN
# 4         NaN        NaN        NaN        NaN         NaN        NaN
#
#    m_chan_EL  m_chan_ELO  m_chan_EO  m_chan_FI  m_chan_FOS  m_chan_HI  \
# 0        NaN         NaN        NaN        NaN         NaN        NaN
# 1        NaN         NaN        NaN        NaN         NaN        NaN
# 2        NaN         NaN        NaN        NaN         NaN        NaN
# 3        NaN         NaN        NaN        NaN         NaN        NaN
# 4        NaN         NaN        NaN        NaN         NaN        NaN
#
#    m_chan_HOM  m_chan_MR  m_chan_PI  m_chan_RFP  m_chan_SED  m_chan_SWD  \
# 0         NaN        NaN        NaN         NaN         NaN         NaN
# 1         NaN        NaN        NaN         NaN         NaN         NaN
# 2         NaN        NaN        NaN         NaN         NaN         NaN
# 3         NaN        NaN        NaN         NaN         NaN         NaN
# 4         NaN        NaN        NaN         NaN         NaN         NaN
#
#    m_chan_WH  m_curr_AA  m_curr_AI  m_curr_ALL  m_curr_AS  m_curr_EL  \
# 0        NaN        NaN        NaN         NaN        NaN        NaN
# 1        NaN        NaN        NaN         NaN        NaN        NaN
# 2        NaN        NaN        NaN         NaN        NaN        NaN
# 3        NaN        NaN        NaN         NaN        NaN        NaN
# 4        NaN        NaN        NaN         NaN        NaN        NaN
#
#    m_curr_ELO  m_curr_EO  m_curr_FI  m_curr_FOS  m_curr_HI  m_curr_HOM  \
# 0         NaN        NaN        NaN         NaN        NaN         NaN
# 1         NaN        NaN        NaN         NaN        NaN         NaN
# 2         NaN        NaN        NaN         NaN        NaN         NaN
# 3         NaN        NaN        NaN         NaN        NaN         NaN
# 4         NaN        NaN        NaN         NaN        NaN         NaN
#
#    m_curr_MR  m_curr_PI  m_curr_RFP  m_curr_SED  m_curr_SWD  m_curr_WH  \
# 0        NaN        NaN         NaN         NaN         NaN        NaN
# 1        NaN        NaN         NaN         NaN         NaN        NaN
# 2        NaN        NaN         NaN         NaN         NaN        NaN
# 3        NaN        NaN         NaN         NaN         NaN        NaN
# 4        NaN        NaN         NaN         NaN         NaN        NaN
#
#    m_prio_AA  m_prio_AI  m_prio_ALL  m_prio_AS  m_prio_EL  m_prio_ELO  \
# 0        NaN        NaN         NaN        NaN        NaN         NaN
# 1        NaN        NaN         NaN        NaN        NaN         NaN
# 2        NaN        NaN         NaN        NaN        NaN         NaN
# 3        NaN        NaN         NaN        NaN        NaN         NaN
# 4        NaN        NaN         NaN        NaN        NaN         NaN
#
#    m_prio_EO  m_prio_FI  m_prio_FOS  m_prio_HI  m_prio_HOM  m_prio_MR  \
# 0        NaN        NaN         NaN        NaN         NaN        NaN
# 1        NaN        NaN         NaN        NaN         NaN        NaN
# 2        NaN        NaN         NaN        NaN         NaN        NaN
# 3        NaN        NaN         NaN        NaN         NaN        NaN
# 4        NaN        NaN         NaN        NaN         NaN        NaN
#
#    m_prio_PI  m_prio_RFP  m_prio_SED  m_prio_SWD  m_prio_WH  \
# 0        NaN         NaN         NaN         NaN        NaN
# 1        NaN         NaN         NaN         NaN        NaN
# 2        NaN         NaN         NaN         NaN        NaN
# 3        NaN         NaN         NaN         NaN        NaN
# 4        NaN         NaN         NaN         NaN        NaN
#
#                                           geometry_x  UPdiff  OBJECTID_y  \
# 0  MULTIPOLYGON (((-13606221.352 4540862.002, -13... -0.0136           1
# 1  POLYGON ((-13612889.056 4565138.930, -13612894...  0.0207           1
# 2  POLYGON ((-13609481.010 4565073.896, -13609481... -0.0179           1
# 3  MULTIPOLYGON (((-13581537.591 4528171.452, -13...  0.0056           1
# 4  POLYGON ((-13614035.309 4555653.898, -13614035...  0.0357           1
#
#   COUNTY_NAM COUNTY_ABB  COUNTY_NUM COUNTY_COD COUNTY_FIP ISLAND  \
# 0    Alameda        ALA           1         01        001   None
# 1    Alameda        ALA           1         01        001   None
# 2    Alameda        ALA           1         01        001   None
# 3    Alameda        ALA           1         01        001   None
# 4    Alameda        ALA           1         01        001   None
#
#                                  GlobalID   SHAPE_Leng_y  SHAPE_Area_y  \
# 0  {E6F92268-D2DD-4CFB-8B79-5B4B2F07C559}  308998.650975  3.402787e+09
# 1  {E6F92268-D2DD-4CFB-8B79-5B4B2F07C559}  308998.650975  3.402787e+09
# 2  {E6F92268-D2DD-4CFB-8B79-5B4B2F07C559}  308998.650975  3.402787e+09
# 3  {E6F92268-D2DD-4CFB-8B79-5B4B2F07C559}  308998.650975  3.402787e+09
# 4  {E6F92268-D2DD-4CFB-8B79-5B4B2F07C559}  308998.650975  3.402787e+09
#
#                                           geometry_y
# 0  POLYGON ((-13611173.233 4566017.932, -13611061...
# 1  POLYGON ((-13611173.233 4566017.932, -13611061...
# 2  POLYGON ((-13611173.233 4566017.932, -13611061...
# 3  POLYGON ((-13611173.233 4566017.932, -13611061...
# 4  POLYGON ((-13611173.233 4566017.932, -13611061...

# %%
overlay = overlay.set_geometry('geometry_x')
# can we have two geometry columns set? Does this give any advantage beyond being able to load all of the data in one file?

# %% [markdown]
# So the merge works, but it might be redundant because I would need to find a way to plot two geometry columns on one plt, the result would be the same as if the gdfs remained unmerged.

# %%
overlay.plot(figsize=(20,20), legend=True, column='UPpct')
