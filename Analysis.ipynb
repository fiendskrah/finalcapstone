# %%
import pandas as pd
import statsmodels.formula.api as smf
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("full_synthesized.csv")
mathpop = pd.read_csv("math.csv")
engpop = pd.read_csv("ela.csv")
#reading in data

# %%
el_math = mathpop.loc[mathpop['studentgroup'] == 'english_learners']
el_eng = engpop.loc[engpop['studentgroup'] == 'english_learners']
# slicing only english learners
el_df = df.merge(el_eng, how='left', on='District Code')
el_df = el_df.merge(el_math, how='left', on='District Code')
# merging grades and funds
el_df.drop('districtname_y', axis=1, inplace=True)
el_df.drop('studentgroup_y', axis=1, inplace=True)
el_df.drop('countyname_y', axis=1, inplace=True)
el_df = el_df.rename(columns={'districtname_x': 'districtname', 'studentgroup_x': 'studentgroup', 'countyname_x': 'countyname'})
# creating english learners dataframe 

low_ses_math = mathpop.loc[mathpop['studentgroup'] == 'ses_disad']
low_ses_eng = engpop.loc[engpop['studentgroup'] == 'ses_disad']
# slicing low ses students
low_ses_df = df.merge(low_ses_eng, how='left', on='District Code')
low_ses_df = low_ses_df.merge(low_ses_math, how='left', on='District Code')
# merging grades and funds
low_ses_df.drop('districtname_y', axis=1, inplace=True)
low_ses_df.drop('studentgroup_y', axis=1, inplace=True)
low_ses_df.drop('countyname_y', axis=1, inplace=True)
low_ses_df = low_ses_df.rename(columns={'districtname_x': 'districtname', 'studentgroup_x': 'studentgroup', 'countyname_x': 'countyname'})
# creating low SES dataframe 

all_math = mathpop.loc[mathpop['studentgroup'] == 'all_students']
all_eng = engpop.loc[engpop['studentgroup'] == 'all_students']
# slicing all students
all_df = df.merge(all_eng, how='left', on='District Code')
all_df = all_df.merge(all_math, how='left', on='District Code')
# merging grades and funds
all_df.drop('districtname_y', axis=1, inplace=True)
all_df.drop('studentgroup_y', axis=1, inplace=True)
all_df.drop('countyname_y', axis=1, inplace=True)
all_df = all_df.rename(columns={'districtname_x': 'districtname', 'studentgroup_x': 'studentgroup', 'countyname_x': 'countyname'})
# creating low SES dataframe 

hisp_math = mathpop.loc[mathpop['studentgroup'] == 'hispanic']
hisp_eng = engpop.loc[engpop['studentgroup'] == 'hispanic']
# slicing only hispanic 
hisp_df = df.merge(hisp_eng, how='left', on='District Code')
hisp_df = hisp_df.merge(hisp_math, how='left', on='District Code')
# merging grades and funds
hisp_df.drop('districtname_y', axis=1, inplace=True)
hisp_df.drop('studentgroup_y', axis=1, inplace=True)
hisp_df.drop('countyname_y', axis=1, inplace=True)
hisp_df = hisp_df.rename(columns={'districtname_x': 'districtname', 'studentgroup_x': 'studentgroup', 'countyname_x': 'countyname'})
# creating hispanic dataframe 

aa_math = mathpop.loc[mathpop['studentgroup'] == 'african_american']
aa_eng = engpop.loc[engpop['studentgroup'] == 'african_american']
# slicing only african american
aa_df = df.merge(aa_eng, how='left', on='District Code')
aa_df = aa_df.merge(aa_math, how='left', on='District Code')
# merging grades and funds
aa_df.drop('districtname_y', axis=1, inplace=True)
aa_df.drop('studentgroup_y', axis=1, inplace=True)
aa_df.drop('countyname_y', axis=1, inplace=True)
aa_df = aa_df.rename(columns={'districtname_x': 'districtname', 'studentgroup_x': 'studentgroup', 'countyname_x': 'countyname'})
# creating african ameriacn dataframe 

a_math = mathpop.loc[mathpop['studentgroup'] == 'asian']
a_eng = engpop.loc[engpop['studentgroup'] == 'asian']
# slicing only asian
a_df = df.merge(a_eng, how='left', on='District Code')
a_df = a_df.merge(a_math, how='left', on='District Code')
# merging grades and funds
a_df.drop('districtname_y', axis=1, inplace=True)
a_df.drop('studentgroup_y', axis=1, inplace=True)
a_df.drop('countyname_y', axis=1, inplace=True)
a_df = a_df.rename(columns={'districtname_x': 'districtname', 'studentgroup_x': 'studentgroup', 'countyname_x': 'countyname'})
# creating asian dataframe 

w_math = mathpop.loc[mathpop['studentgroup'] == 'white']
w_eng = engpop.loc[engpop['studentgroup'] == 'white']
# slicing only white
w_df = df.merge(w_eng, how='left', on='District Code')
w_df = w_df.merge(w_math, how='left', on='District Code')
# merging grades and funds
w_df.drop('districtname_y', axis=1, inplace=True)
w_df.drop('studentgroup_y', axis=1, inplace=True)
w_df.drop('countyname_y', axis=1, inplace=True)
w_df = w_df.rename(columns={'districtname_x': 'districtname', 'studentgroup_x': 'studentgroup', 'countyname_x': 'countyname'})
# creating english learners dataframe

# %%
results = smf.ols(formula='ela_currstatus ~ per_capita_funds*treatment', data=el_df,).fit()
# english learners
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         ela_currstatus   R-squared:                       0.231
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     76.48
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           2.79e-43
# Time:                        13:38:27   Log-Likelihood:                -3689.9
# No. Observations:                 770   AIC:                             7388.
# Df Residuals:                     766   BIC:                             7406.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      9.3239      9.592      0.972      0.331      -9.506      28.154
# ...

# %%
sns.lmplot(x="ela_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=el_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_change ~ per_capita_funds*treatment', data=el_df,).fit()
# english learners
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             ela_change   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     6.307
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           0.000315
# Time:                        13:38:27   Log-Likelihood:                -3030.7
# No. Observations:                 765   AIC:                             6069.
# Df Residuals:                     761   BIC:                             6088.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     18.6925      4.185      4.467      0.000      10.477      26.908
# ...

# %%
sns.lmplot(x="ela_change", y="per_capita_funds", col="treatment", hue="treatment", data=el_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_currstatus ~ per_capita_funds*treatment', data=el_df,).fit()
# english learners
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           m_currstatus   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     64.75
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           2.56e-37
# Time:                        13:38:28   Log-Likelihood:                -3929.2
# No. Observations:                 770   AIC:                             7866.
# Df Residuals:                     766   BIC:                             7885.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -1.5356     13.088     -0.117      0.907     -27.229      24.157
# ...

# %%
sns.lmplot(x="m_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=el_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_change ~ per_capita_funds*treatment', data=el_df,).fit()
# english learners
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               m_change   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     4.931
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):            0.00213
# Time:                        13:38:28   Log-Likelihood:                -2967.7
# No. Observations:                 765   AIC:                             5943.
# Df Residuals:                     761   BIC:                             5962.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     14.7743      3.854      3.833      0.000       7.208      22.340
# ...

# %%
sns.lmplot(x="m_change", y="per_capita_funds", col="treatment", hue="treatment", data=el_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_currstatus ~ per_capita_funds*treatment', data=low_ses_df,).fit()
# socioeconomically disadvantaged 
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         ela_currstatus   R-squared:                       0.230
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                     89.27
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           1.52e-50
# Time:                        13:38:29   Log-Likelihood:                -4141.3
# No. Observations:                 900   AIC:                             8291.
# Df Residuals:                     896   BIC:                             8310.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -12.7254      5.997     -2.122      0.034     -24.495      -0.956
# ...

# %%
sns.lmplot(x="ela_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=low_ses_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_change ~ per_capita_funds*treatment', data=low_ses_df,).fit()
# socioeconomically disadvantaged 
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             ela_change   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     3.395
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):             0.0175
# Time:                        13:38:29   Log-Likelihood:                -3534.4
# No. Observations:                 890   AIC:                             7077.
# Df Residuals:                     886   BIC:                             7096.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      9.4479      3.259      2.899      0.004       3.052      15.843
# ...

# %%
sns.lmplot(x="ela_change", y="per_capita_funds", col="treatment", hue="treatment", data=low_ses_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_currstatus ~ per_capita_funds*treatment', data=low_ses_df,).fit()
# low ses
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           m_currstatus   R-squared:                       0.190
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     69.98
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           1.16e-40
# Time:                        13:38:30   Log-Likelihood:                -4287.1
# No. Observations:                 899   AIC:                             8582.
# Df Residuals:                     895   BIC:                             8601.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -18.0204      7.089     -2.542      0.011     -31.932      -4.108
# ...

# %%
sns.lmplot(x="m_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=low_ses_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_change ~ per_capita_funds*treatment', data=low_ses_df,).fit()
# low ses
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               m_change   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     5.842
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           0.000595
# Time:                        13:38:30   Log-Likelihood:                -3482.8
# No. Observations:                 889   AIC:                             6974.
# Df Residuals:                     885   BIC:                             6993.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      8.9650      3.089      2.902      0.004       2.903      15.027
# ...

# %%
sns.lmplot(x="m_change", y="per_capita_funds", col="treatment", hue="treatment", data=low_ses_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_currstatus ~ per_capita_funds*treatment', data=all_df,).fit()
# all students
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         ela_currstatus   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                     270.8
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):          5.70e-126
# Time:                        13:38:31   Log-Likelihood:                -4396.3
# No. Observations:                 925   AIC:                             8801.
# Df Residuals:                     921   BIC:                             8820.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     32.5227      5.984      5.435      0.000      20.779      44.267
# ...

# %%
sns.lmplot(x="ela_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=all_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_change ~ per_capita_funds*treatment', data=all_df,).fit()
# all students
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             ela_change   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     5.295
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):            0.00127
# Time:                        13:38:31   Log-Likelihood:                -3485.9
# No. Observations:                 923   AIC:                             6980.
# Df Residuals:                     919   BIC:                             6999.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      9.5237      2.306      4.130      0.000       4.998      14.049
# ...

# %%
sns.lmplot(x="ela_change", y="per_capita_funds", col="treatment", hue="treatment", data=all_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_currstatus ~ per_capita_funds*treatment', data=all_df,).fit()
# all students
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           m_currstatus   R-squared:                       0.436
# Model:                            OLS   Adj. R-squared:                  0.434
# Method:                 Least Squares   F-statistic:                     237.2
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):          5.54e-114
# Time:                        13:38:32   Log-Likelihood:                -4545.9
# No. Observations:                 924   AIC:                             9100.
# Df Residuals:                     920   BIC:                             9119.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     25.7081      7.073      3.635      0.000      11.828      39.588
# ...

# %%
sns.lmplot(x="m_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=all_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_change ~ per_capita_funds*treatment', data=all_df,).fit()
# all students
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               m_change   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     2.705
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):             0.0443
# Time:                        13:38:32   Log-Likelihood:                -3508.5
# No. Observations:                 922   AIC:                             7025.
# Df Residuals:                     918   BIC:                             7044.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      7.7388      2.373      3.261      0.001       3.082      12.396
# ...

# %%
sns.lmplot(x="m_change", y="per_capita_funds", col="treatment", hue="treatment", data=all_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_currstatus ~ per_capita_funds*treatment', data=hisp_df,).fit()
# hispanic
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         ela_currstatus   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     113.9
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           5.98e-62
# Time:                        13:38:33   Log-Likelihood:                -3936.4
# No. Observations:                 850   AIC:                             7881.
# Df Residuals:                     846   BIC:                             7900.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      4.9042      6.959      0.705      0.481      -8.755      18.564
# ...

# %%
sns.lmplot(x="ela_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=hisp_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_change ~ per_capita_funds*treatment', data=hisp_df,).fit()
# hispanic
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             ela_change   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     3.473
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):             0.0157
# Time:                        13:38:33   Log-Likelihood:                -3292.6
# No. Observations:                 846   AIC:                             6593.
# Df Residuals:                     842   BIC:                             6612.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      9.8442      3.324      2.962      0.003       3.320      16.369
# ...

# %%
sns.lmplot(x="ela_change", y="per_capita_funds", col="treatment", hue="treatment", data=hisp_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_currstatus ~ per_capita_funds*treatment', data=hisp_df,).fit()
# hispanic
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           m_currstatus   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     100.4
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           1.41e-55
# Time:                        13:38:34   Log-Likelihood:                -4065.6
# No. Observations:                 850   AIC:                             8139.
# Df Residuals:                     846   BIC:                             8158.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      3.8486      8.101      0.475      0.635     -12.053      19.750
# ...

# %%
sns.lmplot(x="m_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=hisp_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_change ~ per_capita_funds*treatment', data=hisp_df,).fit()
# hispanic
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               m_change   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     3.457
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):             0.0161
# Time:                        13:38:34   Log-Likelihood:                -3245.7
# No. Observations:                 846   AIC:                             6499.
# Df Residuals:                     842   BIC:                             6518.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      9.9176      3.145      3.154      0.002       3.745      16.090
# ...

# %%
sns.lmplot(x="m_change", y="per_capita_funds", col="treatment", hue="treatment", data=hisp_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_currstatus ~ per_capita_funds*treatment', data=aa_df,).fit()
# african american 
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         ela_currstatus   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     59.14
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           5.75e-32
# Time:                        13:38:35   Log-Likelihood:                -2049.3
# No. Observations:                 429   AIC:                             4107.
# Df Residuals:                     425   BIC:                             4123.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      8.9684     16.600      0.540      0.589     -23.659      41.596
# ...

# %%
sns.lmplot(x="ela_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=aa_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_change ~ per_capita_funds*treatment', data=aa_df,).fit()
# african american 
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             ela_change   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.7630
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):              0.515
# Time:                        13:38:36   Log-Likelihood:                -1751.0
# No. Observations:                 411   AIC:                             3510.
# Df Residuals:                     407   BIC:                             3526.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     15.4345     10.984      1.405      0.161      -6.158      37.028
# ...

# %%
sns.lmplot(x="ela_change", y="per_capita_funds", col="treatment", hue="treatment", data=aa_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_currstatus ~ per_capita_funds*treatment', data=aa_df,).fit()
# african american 
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           m_currstatus   R-squared:                       0.303
# Model:                            OLS   Adj. R-squared:                  0.298
# Method:                 Least Squares   F-statistic:                     61.21
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           7.16e-33
# Time:                        13:38:36   Log-Likelihood:                -2081.7
# No. Observations:                 426   AIC:                             4171.
# Df Residuals:                     422   BIC:                             4188.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -1.8208     18.566     -0.098      0.922     -38.314      34.672
# ...

# %%
sns.lmplot(x="m_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=aa_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_change ~ per_capita_funds*treatment', data=aa_df,).fit()
# african american 
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               m_change   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.7561
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):              0.519
# Time:                        13:38:37   Log-Likelihood:                -1671.5
# No. Observations:                 409   AIC:                             3351.
# Df Residuals:                     405   BIC:                             3367.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -12.8924      9.258     -1.393      0.165     -31.093       5.308
# ...

# %%
sns.lmplot(x="m_change", y="per_capita_funds", col="treatment", hue="treatment", data=aa_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_currstatus ~ per_capita_funds*treatment', data=a_df,).fit()
# asian
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         ela_currstatus   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.314
# Method:                 Least Squares   F-statistic:                     74.60
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           1.31e-39
# Time:                        13:38:37   Log-Likelihood:                -2407.8
# No. Observations:                 483   AIC:                             4824.
# Df Residuals:                     479   BIC:                             4840.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     40.2252     16.336      2.462      0.014       8.126      72.324
# ...

# %%
sns.lmplot(x="ela_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=a_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_change ~ per_capita_funds*treatment', data=a_df,).fit()
# asian
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             ela_change   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.772
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):              0.152
# Time:                        13:38:38   Log-Likelihood:                -1862.5
# No. Observations:                 471   AIC:                             3733.
# Df Residuals:                     467   BIC:                             3750.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     15.2179      5.868      2.593      0.010       3.687      26.749
# ...

# %%
sns.lmplot(x="ela_change", y="per_capita_funds", col="treatment", hue="treatment", data=a_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_currstatus ~ per_capita_funds*treatment', data=a_df,).fit()
# asian
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           m_currstatus   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     89.50
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           5.41e-46
# Time:                        13:38:39   Log-Likelihood:                -2468.0
# No. Observations:                 483   AIC:                             4944.
# Df Residuals:                     479   BIC:                             4961.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     49.6761     18.504      2.685      0.008      13.317      86.036
# ...

# %%
sns.lmplot(x="m_currstatus", y="per_capita_funds", col="treatment", hue="treatment", data=a_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='m_change ~ per_capita_funds*treatment', data=a_df,).fit()
# asian
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               m_change   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     2.891
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):             0.0351
# Time:                        13:38:39   Log-Likelihood:                -1856.6
# No. Observations:                 471   AIC:                             3721.
# Df Residuals:                     467   BIC:                             3738.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     14.5883      5.794      2.518      0.012       3.202      25.974
# ...

# %%
sns.lmplot(x="m_change", y="per_capita_funds", col="treatment", hue="treatment", data=a_df,
           ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 15, "alpha": 1}
          )

# %%
results = smf.ols(formula='ela_currstatus ~ per_capita_funds*treatment', data=w_df,).fit()
# white
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         ela_currstatus   R-squared:                       0.308
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     127.3
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           3.62e-68
# Time:                        13:38:40   Log-Likelihood:                -4163.8
# No. Observations:                 860   AIC:                             8336.
# Df Residuals:                     856   BIC:                             8355.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     37.7401      6.914      5.458      0.000      24.169      51.311
# ...

# %%
results = smf.ols(formula='m_currstatus ~ per_capita_funds*treatment', data=w_df,).fit()
# white
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           m_currstatus   R-squared:                       0.331
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     141.3
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           2.20e-74
# Time:                        13:38:40   Log-Likelihood:                -4224.8
# No. Observations:                 860   AIC:                             8458.
# Df Residuals:                     856   BIC:                             8477.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     28.9466      7.422      3.900      0.000      14.378      43.515
# ...
